# %%
import sys
import os

if 'google.colab' in sys.modules:
    print("☁️ Google Colab detected. Setting up GitHub repository...")
    if not os.path.exists('manero-panganiban-serafica'):
        # !git clone https://github.com/kricme/manero-panganiban-serafica.git
    if not os.getcwd().endswith('04 Transformer-based Sentiment Analysis/0401 BERT models'):
        # %cd "manero-panganiban-serafica/04 Transformer-based Sentiment Analysis/0401 BERT models"
else:
    print("💻 Local environment detected. Using local file paths.")
# Out:
# ☁️ Google Colab detected. Setting up GitHub repository...
# Cloning into 'manero-panganiban-serafica'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 136 (delta 43), reused 54 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 16.24 MiB | 19.65 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/manero-panganiban-serafica/04 Transformer-based Sentiment Analysis/0401 BERT models

# %%
# Uncomment the next line in Colab or local if needed
# !pip install -q pandas numpy nltk torch transformers tqdm matplotlib

import os, math, numpy as np, pandas as pd, nltk, torch, matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Ensure NLTK sentence tokenizer is available
try:
    nltk.data.find("tokenizers/punkt")
except LookupError:
    nltk.download("punkt")
try:
    nltk.data.find("tokenizers/punkt_tab")
except LookupError:
    try: nltk.download("punkt_tab")
    except: pass
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
INPUT_CSV = "../../00 Cleaned Dataset/01 speech dataset/bsp_speech_dataset.csv"
ID_COL, DATE_COL, TEXT_COL = "index", "Date", "Text"

# Output directory
OUT_DIR = "../../00 Cleaned Dataset/05 Exploratory and Baseline Models/Base BERT Baselines"
os.makedirs(OUT_DIR, exist_ok=True)

# Model
MODEL_NAME = "cardiffnlp/twitter-roberta-base-sentiment-latest"  # 3-class sentiment

MAX_LENGTH, BATCH_SIZE = 512, 32
print(f"Input: {INPUT_CSV}\\nOutputs → {OUT_DIR}\\nModel → {MODEL_NAME}")
# Out:
# Input: ../../00 Cleaned Dataset/01 speech dataset/bsp_speech_dataset.csv\nOutputs → ../../00 Cleaned Dataset/05 Exploratory and Baseline Models/Base BERT Baselines\nModel → cardiffnlp/twitter-roberta-base-sentiment-latest

# %%
df = pd.read_csv(INPUT_CSV)
ID_COL, DATE_COL, TEXT_COL = "index", "Date", "Text"
missing = [c for c in [ID_COL, DATE_COL, TEXT_COL] if c not in df.columns]
if missing: raise ValueError(f"Missing columns: {missing}")

df[DATE_COL] = pd.to_datetime(df[DATE_COL], errors="coerce")
if df[DATE_COL].isna().any():
    bad = df[df[DATE_COL].isna()]
    raise ValueError("Unparseable dates:", bad[[ID_COL, DATE_COL]].head())

print("Rows:", len(df), "| Unique speeches:", df[ID_COL].nunique())
df.head(3)
# Out:
# Rows: 673 | Unique speeches: 673
#    index                                              Title       Date  \
# 0      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 1      1        Finding Opportunities in a Borderless World 2020-02-28
# 2      2  Gearing up for the Road Ahead: With Foresight ... 2020-02-27
#
#                           Location  \
# 0  Dusit Thani Manila, Makati City
# 1                 El Nido, Palawan
# 2   Sofitel Philippine Plaza Hotel
#
#                                             Occasion             Speaker  \
# 0               The Manila Times 11th Business Forum  Benjamin E. Diokno
# 1                        13th Annual FMAP Convention  Benjamin E. Diokno
# 2  17th Professional Insurance and Financial Advi...  Benjamin E. Diokno
#
#        Role                                               Text   Len  \
# 0  Governor  The Manila Times President and CEO, Mr. Dante ...  2442
# 1  Governor  To the officers and members of the Fund Manage...  2672
# 2  Governor  Officers and members of the Professional Insur...  2922
#
#                                                 Link last_name  year
# 0  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 1  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 2  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020

# %%
df_sent = (df
           .assign(_sents=lambda d: d[TEXT_COL].fillna("").apply(sent_tokenize))
           .explode("_sents")
           .rename(columns={"_sents": "sentence"})
           .reset_index(drop=True))

df_sent["sentence"] = df_sent["sentence"].fillna("").str.strip()
df_sent = df_sent[df_sent["sentence"].str.len() > 0]
print("Total sentences:", len(df_sent), "from", df[ID_COL].nunique(), "speeches")
df_sent.head(6)
# Out:
# Total sentences: 43538 from 673 speeches
#    index                                              Title       Date  \
# 0      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 1      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 2      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 3      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 4      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 5      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
#
#                           Location                              Occasion  \
# 0  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 1  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 2  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 3  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 4  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 5  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
#
#               Speaker      Role  \
# 0  Benjamin E. Diokno  Governor
# 1  Benjamin E. Diokno  Governor
# 2  Benjamin E. Diokno  Governor
# 3  Benjamin E. Diokno  Governor
# 4  Benjamin E. Diokno  Governor
# 5  Benjamin E. Diokno  Governor
#
#                                                 Text   Len  \
# 0  The Manila Times President and CEO, Mr. Dante ...  2442
# 1  The Manila Times President and CEO, Mr. Dante ...  2442
# 2  The Manila Times President and CEO, Mr. Dante ...  2442
# 3  The Manila Times President and CEO, Mr. Dante ...  2442
# 4  The Manila Times President and CEO, Mr. Dante ...  2442
# 5  The Manila Times President and CEO, Mr. Dante ...  2442
#
#                                                 Link last_name  year  \
# 0  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 1  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 2  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 3  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 4  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 5  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
#
#                                             sentence
# 0  The Manila Times President and CEO, Mr. Dante ...
# 1  It is a pleasure to be joining today's Busines...
# 2  In line with the conference theme and given th...
# 3  High and volatile inflation is undesirable bec...
# 4  Until recently, the Philippines is characteriz...
# 5           In 2002, onward this trend was reversed.

# %%
df_sent = (df
           .assign(_sents=lambda d: d[TEXT_COL].fillna("").apply(sent_tokenize))
           .explode("_sents")
           .rename(columns={"_sents": "sentence"})
           .reset_index(drop=True))

df_sent["sentence"] = df_sent["sentence"].fillna("").str.strip()
df_sent = df_sent[df_sent["sentence"].str.len() > 0]
print("Total sentences:", len(df_sent), "from", df[ID_COL].nunique(), "speeches")
df_sent.head(6)
# Out:
# Total sentences: 43538 from 673 speeches
#    index                                              Title       Date  \
# 0      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 1      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 2      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 3      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 4      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 5      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
#
#                           Location                              Occasion  \
# 0  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 1  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 2  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 3  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 4  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 5  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
#
#               Speaker      Role  \
# 0  Benjamin E. Diokno  Governor
# 1  Benjamin E. Diokno  Governor
# 2  Benjamin E. Diokno  Governor
# 3  Benjamin E. Diokno  Governor
# 4  Benjamin E. Diokno  Governor
# 5  Benjamin E. Diokno  Governor
#
#                                                 Text   Len  \
# 0  The Manila Times President and CEO, Mr. Dante ...  2442
# 1  The Manila Times President and CEO, Mr. Dante ...  2442
# 2  The Manila Times President and CEO, Mr. Dante ...  2442
# 3  The Manila Times President and CEO, Mr. Dante ...  2442
# 4  The Manila Times President and CEO, Mr. Dante ...  2442
# 5  The Manila Times President and CEO, Mr. Dante ...  2442
#
#                                                 Link last_name  year  \
# 0  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 1  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 2  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 3  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 4  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 5  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
#
#                                             sentence
# 0  The Manila Times President and CEO, Mr. Dante ...
# 1  It is a pleasure to be joining today's Busines...
# 2  In line with the conference theme and given th...
# 3  High and volatile inflation is undesirable bec...
# 4  Until recently, the Philippines is characteriz...
# 5           In 2002, onward this trend was reversed.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)
model.to(device).eval()

id2label = getattr(model.config, "id2label", {0:"negative",1:"neutral",2:"positive"})
print("id2label:", id2label)
# Out:
# Using device: cuda
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# id2label: {0: 'negative', 1: 'neutral', 2: 'positive'}

# %%
def softmax_np(x):
    x -= np.max(x, axis=-1, keepdims=True)
    e = np.exp(x)
    return e/np.sum(e, axis=-1, keepdims=True)

CANON = ["negative","neutral","positive"]
label_texts = {int(k):str(v).lower() for k,v in id2label.items()}
try:
    canon_indices=[ [i for i,l in label_texts.items() if l==n][0] for n in CANON]
except: canon_indices=[0,1,2]

sents=df_sent["sentence"].tolist()
p_neg,p_neu,p_pos=np.zeros(len(sents)),np.zeros(len(sents)),np.zeros(len(sents))

print("Scoring sentences…")
for i in tqdm(range(0,len(sents),BATCH_SIZE)):
    enc=tokenizer(sents[i:i+BATCH_SIZE],padding=True,truncation=True,max_length=MAX_LENGTH,return_tensors="pt").to(device)
    with torch.no_grad(): logits=model(**enc).logits.cpu().numpy()
    probs=softmax_np(logits)[:,canon_indices]
    p_neg[i:i+len(probs)]=probs[:,0]; p_neu[i:i+len(probs)]=probs[:,1]; p_pos[i:i+len(probs)]=probs[:,2]

df_sent["p_neg"],df_sent["p_neu"],df_sent["p_pos"]=p_neg,p_neu,p_pos
df_sent["tone"]=df_sent["p_pos"]-df_sent["p_neg"]
df_sent["label"]=["negative","neutral","positive"][0]
df_sent["label"]=[["negative","neutral","positive"][int(np.argmax(x))] for x in np.stack([p_neg,p_neu,p_pos],1)]

df_sent.head(6)
# Out:
# Scoring sentences…
# 100%|██████████| 1361/1361 [02:31<00:00,  9.01it/s]
#    index                                              Title       Date  \
# 0      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 1      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 2      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 3      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 4      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
# 5      0  Staying on Track in 2020: Sustaining Positive ... 2020-03-03
#
#                           Location                              Occasion  \
# 0  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 1  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 2  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 3  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 4  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
# 5  Dusit Thani Manila, Makati City  The Manila Times 11th Business Forum
#
#               Speaker      Role  \
# 0  Benjamin E. Diokno  Governor
# 1  Benjamin E. Diokno  Governor
# 2  Benjamin E. Diokno  Governor
# 3  Benjamin E. Diokno  Governor
# 4  Benjamin E. Diokno  Governor
# 5  Benjamin E. Diokno  Governor
#
#                                                 Text   Len  \
# 0  The Manila Times President and CEO, Mr. Dante ...  2442
# 1  The Manila Times President and CEO, Mr. Dante ...  2442
# 2  The Manila Times President and CEO, Mr. Dante ...  2442
# 3  The Manila Times President and CEO, Mr. Dante ...  2442
# 4  The Manila Times President and CEO, Mr. Dante ...  2442
# 5  The Manila Times President and CEO, Mr. Dante ...  2442
#
#                                                 Link last_name  year  \
# 0  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 1  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 2  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 3  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 4  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
# 5  https://www.bsp.gov.ph/SitePages/MediaAndResea...    Diokno  2020
#
#                                             sentence     p_neg     p_neu  \
# 0  The Manila Times President and CEO, Mr. Dante ...  0.002742  0.134767
# 1  It is a pleasure to be joining today's Busines...  0.001763  0.033757
# 2  In line with the conference theme and given th...  0.004792  0.587780
# 3  High and volatile inflation is undesirable bec...  0.879208  0.113224
# 4  Until recently, the Philippines is characteriz...  0.482534  0.499208
# 5           In 2002, onward this trend was reversed.  0.126188  0.840635
#
#       p_pos      tone     label
# 0  0.862491  0.859749  positive
# 1  0.964480  0.962718  positive
# 2  0.407428  0.402636   neutral
# 3  0.007568 -0.871641  negative
# 4  0.018259 -0.464275   neutral
# 5  0.033176 -0.093012   neutral

# %%
sent_path=os.path.join(OUT_DIR,"roberta_sentences_scored.csv")
df_sent[[ID_COL,DATE_COL,"sentence","p_neg","p_neu","p_pos","tone","label"]].to_csv(sent_path,index=False)
print("Saved:",sent_path)

plt.figure(figsize=(6,4))
df_sent["tone"].hist(bins=50)
plt.title("Distribution of Sentence Tone (p_pos − p_neg)")
plt.xlabel("tone"); plt.ylabel("count"); plt.show()
# Out:
# Saved: ../../00 Cleaned Dataset/05 Exploratory and Baseline Models/Base BERT Baselines/roberta_sentences_scored.csv

# %%
def share_over(x,thr=.5): return (x>thr).mean()
def majority_label(x): return x.value_counts().idxmax()

agg=(df_sent.groupby([ID_COL,DATE_COL],as_index=False)
     .agg(tone_mean=("tone","mean"),
          tone_median=("tone","median"),
          pos_share=("p_pos",share_over),
          neg_share=("p_neg",share_over),
          neu_share=("p_neu",share_over),
          n_sent=("sentence","count")))
maj=df_sent.groupby([ID_COL,DATE_COL])["label"].apply(majority_label).reset_index(name="label_majority")
speech_df=agg.merge(maj,on=[ID_COL,DATE_COL],how="left")

speech_path=os.path.join(OUT_DIR,"roberta_speeches_agg.csv")
speech_df.to_csv(speech_path,index=False)
print("Saved:",speech_path)
speech_df.head(10)
# Out:
# Saved: ../../00 Cleaned Dataset/05 Exploratory and Baseline Models/Base BERT Baselines/roberta_speeches_agg.csv
#    index       Date  tone_mean  tone_median  pos_share  neg_share  neu_share  \
# 0      0 2020-03-03   0.285007     0.280469   0.391753   0.082474   0.515464
# 1      1 2020-02-28   0.455530     0.536039   0.528000   0.024000   0.424000
# 2      2 2020-02-27   0.393128     0.448657   0.476562   0.070312   0.437500
# 3      3 2020-02-06   0.369265     0.417812   0.465909   0.068182   0.465909
# 4      4 2020-01-31   0.636226     0.740745   0.750000   0.000000   0.200000
# 5      5 2020-01-30   0.365858     0.340388   0.366279   0.029070   0.598837
# 6      6 2020-01-28   0.513213     0.561176   0.553719   0.024793   0.404959
# 7      7 2020-01-24   0.496346     0.618006   0.585714   0.028571   0.371429
# 8      8 2020-01-21   0.217641     0.083510   0.272727   0.060606   0.666667
# 9      9 2020-01-09   0.382031     0.460937   0.470588   0.036765   0.477941
#
#    n_sent label_majority
# 0      97        neutral
# 1     125       positive
# 2     128       positive
# 3      88        neutral
# 4      20       positive
# 5     172        neutral
# 6     121       positive
# 7      70       positive
# 8      33        neutral
# 9     136        neutral

# %%
daily=(speech_df.groupby(DATE_COL,as_index=False)["tone_mean"].mean().sort_values(DATE_COL))
plt.figure(figsize=(8,4))
plt.plot(daily[DATE_COL],daily["tone_mean"],lw=2)
plt.title("Average Speech Tone Over Time")
plt.xlabel("date"); plt.ylabel("tone_mean"); plt.tight_layout(); plt.show()

plt.figure(figsize=(6,4))
speech_df["n_sent"].hist(bins=30)
plt.title("Sentence Count per Speech"); plt.xlabel("n_sent"); plt.ylabel("count")
plt.tight_layout(); plt.show()

# %%
# Resample to monthly average
monthly = daily.set_index(DATE_COL).resample("M").mean()

plt.figure(figsize=(10,5))
plt.plot(monthly.index, monthly["tone_mean"], color="royalblue", linewidth=2)
plt.title("Average Speech Tone (Monthly Mean)")
plt.xlabel("Date")
plt.ylabel("Tone")
plt.tight_layout()
plt.show()

# Optional: yearly smoother
yearly = daily.set_index(DATE_COL).resample("Y").mean()
plt.figure(figsize=(9,4))
plt.plot(yearly.index, yearly["tone_mean"], marker='o', color="firebrick")
plt.title("Average Speech Tone (Yearly Mean)")
plt.xlabel("Year")
plt.ylabel("Tone")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1880/2589621125.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = daily.set_index(DATE_COL).resample("M").mean()
# /tmp/ipykernel_1880/2589621125.py:13: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly = daily.set_index(DATE_COL).resample("Y").mean()

# %%
daily = daily.set_index(DATE_COL).sort_index()
# 180-day (≈6-month) rolling average
daily["tone_6mo"] = daily["tone_mean"].rolling("180D", min_periods=1).mean()

plt.figure(figsize=(10,5))
plt.plot(daily.index, daily["tone_mean"], color="lightgray", alpha=0.5, label="Raw tone")
plt.plot(daily.index, daily["tone_6mo"], color="darkgreen", linewidth=2, label="6-month moving average")
plt.title("Average Speech Tone (6-Month Rolling Mean)")
plt.xlabel("Date")
plt.ylabel("Tone")
plt.legend()
plt.tight_layout()
plt.show()

# %%
## VISUALIZATION

# df_sent already contains the 'Date' column as datetime and 'tone' column

plt.figure(figsize=(12,5))
plt.scatter(df_sent["Date"], df_sent["tone"], s=10, alpha=0.5, color="darkgreen")
plt.title("Sentence-Level Tone Over Time")
plt.xlabel("Date")
plt.ylabel("Tone (p_pos − p_neg)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Rolling average (30-day window)
daily_mean = df_sent.groupby(DATE_COL)["tone"].mean().rolling(30, min_periods=1).mean()
plt.figure(figsize=(12,5))
plt.plot(daily_mean.index, daily_mean.values, color="blue", linewidth=2)
plt.title("30-Day Rolling Average of Sentence-Level Tone")
plt.xlabel("Date")
plt.ylabel("Average Tone")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
